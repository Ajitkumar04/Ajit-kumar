# %%
import pandas as pd
import numpy as  np
import json

# %%
data=pd.read_json("C:\\Users\\a\\OneDrive\\Desktop\\AL ML PATNA\data\data\\trend_20240115.json")

# %%
data.head()
# Out:
#     post_id                                              title    category  \
# 0  47655408  Show HN: I built a tiny LLM to demystify how l...  technology
# 1  47658146    France pulls last gold held in US for $15B gain  technology
# 2  47622591                           Jobs Being Created by AI  technology
# 3  47655367  Show HN: Gemma Gem – AI model embedded in a br...  technology
# 4  47652007  Show HN: Real-time AI (audio/video in, voice o...  technology
#
#    score  num_comments      author               collected_at
# 0    437            41  armanified 2026-04-06 14:45:00.907628
# 1     53            32   teleforce 2026-04-06 14:45:02.028235
# 2      9             3    Jimmc414 2026-04-06 14:45:11.403969
# 3     75            14    ikessler 2026-04-06 14:45:12.495743
# 4     79             4      karimf 2026-04-06 14:45:16.003689

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# post_id         0
# title           0
# category        0
# score           0
# num_comments    0
# author          0
# collected_at    0
# dtype: int64

# %%
data.dtypes
# Out:
# post_id                  int64
# title                   object
# category                object
# score                    int64
# num_comments             int64
# author                  object
# collected_at    datetime64[ns]
# dtype: object

# %%
data=data[data["score"]>=5]

# %%
data.shape
# Out:
# (78, 7)

# %%
data["title"]=data["title"].str.strip( )

# %%
data
# Out:
#      post_id                                              title  \
# 0   47655408  Show HN: I built a tiny LLM to demystify how l...
# 1   47658146    France pulls last gold held in US for $15B gain
# 2   47622591                           Jobs Being Created by AI
# 3   47655367  Show HN: Gemma Gem – AI model embedded in a br...
# 4   47652007  Show HN: Real-time AI (audio/video in, voice o...
# ..       ...                                                ...
# 75  47638532  Show HN: Ownscribe – local meeting transcripti...
# 76  47632692  Show HN: Mtproto.zig – High-performance Telegr...
# 77  47631030  Show HN: Ismcpdead.com – Live dashboard tracki...
# 78  47612601  Sweden goes back to basics, swapping screens f...
# 79  47643580  Show HN: Uncompressed – Self-hosted Netflix al...
#
#          category  score  num_comments         author  \
# 0      technology    437            41     armanified
# 1      technology     53            32      teleforce
# ...

# %%
data.to_csv("trends_clean.csv",index=False)
